# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasbarreto03/T-cnicas_de_Programa-o/blob/main/engenharia_software_6_nov_LucasEduardo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula do dia 06/11/2025 - OPERADORES

# %%
2**3
# Out:
# 8

# %%
23//7
# Out:
# 3

# %%
23%7
# Out:
# 2

# %%
5+5*5 /5
# Out:
# 10.0

# %%
4**(4/2)+7
# Out:
# 23.0

# %%
# questao 1
a = int(input("informe um numero: "))
b = int(input("informe o segundo numero: "))
a+b
# Out:
# informe um numero: 1
# informe o segundo numero: 2
# 3

# %%
#questao 2
n1 = float(input("informe a primeira nota: "))
n2 = float(input("informe a segunda nota: "))
media = (n1+n2)/2
print("media: ", media)
# Out:
# informe a primeira nota: 10
# informe a segunda nota: 8
# media:  9.0

# %%
# questao 3
nome= "Vítor"
print(f"Olá, {nome}!")
# Out:
# Olá, Vítor!

# %%
# questao 4
nome_usuario = input("informe seu nome: ")
ano_nascimento = input("informe seu ano de nascimento: ")
print(f"{nome_usuario} nasceu em {ano_nascimento}.")
# Out:
# informe seu nome: Lucas
# informe seu ano de nascimento: 2003
# Lucas nasceu em 2003.

# %%
# questao 5
nome_usuario = input("informe seu nome: ")
print(f"Olá, {nome_usuario}!")
ano_nascimento = input("informe seu ano de nascimento: ")
idade= 2025 - int(ano_nascimento)
print(f"{nome_usuario} tem {idade}, {nome_usuario * idade}")
# Out:
# informe seu nome: Lucas
# Olá, Lucas!
# informe seu ano de nascimento: 2003
# Lucas tem 22, LucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucasLucas

# %%
# questao 6
n1 = float(input("informe a primeira nota: "))
n2 = float(input("informe a segunda nota: "))
n3 = float(input("informe a terceira nota: "))
p1 = 1
p2 = 1
p3 = 1
media = (n1*p1 + n2*p2 + n3*p3) / (p1 + p2 + p3)
print("A média ponderada é: ", media)
# Out:
# informe a primeira nota: 10
# informe a segunda nota: 5
# informe a terceira nota: 6
# A média ponderada é:  7.0

# %%
# questao 7
n1 = float(input("informe a primeira nota: "))
p1 = float(input("informe o peso da primeira nota: "))
n2 = float(input("informe a segunda nota: "))
p2 = float(input("informe o peso da segunda nota: "))
n3 = float(input("informe a terceira nota: "))
p3 = float(input("informe o peso da terceira nota: "))
media = (n1*p1 + n2*p2 + n3*p3) / (p1 + p2 + p3)
print("A média ponderada é: ", media)
# Out:
# informe a primeira nota: 10
# informe o peso da primeira nota: 3
# informe a segunda nota: 5
# informe o peso da segunda nota: 2
# informe a terceira nota: 8
# informe o peso da terceira nota: 2
# A média ponderada é:  8.0

# %%
#questão 8
n = input("Digite um número: ")
soma = 0
for x in n:
    soma = soma + int(x)
print("A soma é:", soma)
# Out:
# Digite um número: 10
# A soma é: 1

# %%
#questão 9
palavra = input("Digite uma palavra: ")
invertida = palavra[::-1]
print("A palavra invertida é:", invertida)
# Out:
# Digite uma palavra: lucas
# A palavra invertida é: sacul
